# %% [markdown]
# <a href="https://colab.research.google.com/github/spaceo521/Data-Science-Projects/blob/main/Untitled23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('ODI_data.csv')

# %%
df.head(2)
# Out:
#   Innings Player Innings Runs Scored Innings Runs Scored Num  \
# 0        E Lewis                  65                      65
# 1       N Pooran                  42                      42
#
#   Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 0                    128                  1.0                   0.0
# 1                     69                  1.0                   0.0
#
#   Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# 0                  80                      8                      1
# 1                  52                      4                      1
#
#   Innings Batting Strike Rate  ... Innings Overs Bowled Innings Bowled Flag  \
# 0                       81.25  ...                  NaN                 NaN
# 1                       80.76  ...                  NaN                 NaN
#
#   Innings Maidens Bowled Innings Runs Conceded Innings Wickets Taken  \
# ...

# %%
df.columns
# Out:
# Index(['Innings Player', 'Innings Runs Scored', 'Innings Runs Scored Num',
#        'Innings Minutes Batted', 'Innings Batted Flag', 'Innings Not Out Flag',
#        'Innings Balls Faced', 'Innings Boundary Fours',
#        'Innings Boundary Sixes', 'Innings Batting Strike Rate',
#        'Innings Number', 'Opposition', 'Ground', 'Innings Date', 'Country',
#        '50's', '100's', 'Innings Runs Scored Buckets', 'Innings Overs Bowled',
#        'Innings Bowled Flag', 'Innings Maidens Bowled',
#        'Innings Runs Conceded', 'Innings Wickets Taken', '4 Wickets',
#        '5 Wickets', '10 Wickets', 'Innings Wickets Taken Buckets',
#        'Innings Economy Rate'],
#       dtype='object')

# %%
df['Innings Runs Scored Num'].unique()
# Out:
# array(['65', '42', '18', '17', '13', '11', '5', '0', '120', '71', '20',
#        '16', '3', '2', '1', '-', nan, '40', '6', '4', '87', '54', '46',
#        '30', '12', '69', '39', '14', '10', '9', '8', '7', '82', '52',
#        '41', '15', '98', '43', '19', '111', '48', '36', '25', '67', '60',
#        '84', '59', '55', '47', '85', '49', '45', '34', '29', '22', '74',
#        '28', '77', '50', '32', '23', '35', '122', '100', '95', '103',
#        '113', '53', '96', '27', '64', '58', '33', '31', '73', '56', '86',
#        '62', '106', '24', '57', '104', '26', '66', '51', '118', '105',
#        '101', '21', '79', '44', '102', '88', '80', '72', '97', '68', '89',
#        '38', '83', '63', '148', '166', '90', '76', '37', '70', '124',
#        '94', '140', '153', '107', '117', '121', '92', '78', '75', '114',
#        '115', '130', '128', '151', '110', '138', '135', '109', '61',
#        '179', '170', '112', '116', '91', '143', '93', '123', '145', '81',
# ...

# %%
df = df[df['Innings Runs Scored Num'] != '-']

# %%
df['Innings Runs Scored Num'].unique()
# Out:
# array(['65', '42', '18', '17', '13', '11', '5', '0', '120', '71', '20',
#        '16', '3', '2', '1', nan, '40', '6', '4', '87', '54', '46', '30',
#        '12', '69', '39', '14', '10', '9', '8', '7', '82', '52', '41',
#        '15', '98', '43', '19', '111', '48', '36', '25', '67', '60', '84',
#        '59', '55', '47', '85', '49', '45', '34', '29', '22', '74', '28',
#        '77', '50', '32', '23', '35', '122', '100', '95', '103', '113',
#        '53', '96', '27', '64', '58', '33', '31', '73', '56', '86', '62',
#        '106', '24', '57', '104', '26', '66', '51', '118', '105', '101',
#        '21', '79', '44', '102', '88', '80', '72', '97', '68', '89', '38',
#        '83', '63', '148', '166', '90', '76', '37', '70', '124', '94',
#        '140', '153', '107', '117', '121', '92', '78', '75', '114', '115',
#        '130', '128', '151', '110', '138', '135', '109', '61', '179',
#        '170', '112', '116', '91', '143', '93', '123', '145', '81', '150',
# ...

# %%
df = df[(df['Innings Runs Scored Num'] != '-') & (df['Innings Runs Scored Num'].notna())]

# %%
df['Innings Runs Scored Num'].unique()
# Out:
# array(['65', '42', '18', '17', '13', '11', '5', '0', '120', '71', '20',
#        '16', '3', '2', '1', '40', '6', '4', '87', '54', '46', '30', '12',
#        '69', '39', '14', '10', '9', '8', '7', '82', '52', '41', '15',
#        '98', '43', '19', '111', '48', '36', '25', '67', '60', '84', '59',
#        '55', '47', '85', '49', '45', '34', '29', '22', '74', '28', '77',
#        '50', '32', '23', '35', '122', '100', '95', '103', '113', '53',
#        '96', '27', '64', '58', '33', '31', '73', '56', '86', '62', '106',
#        '24', '57', '104', '26', '66', '51', '118', '105', '101', '21',
#        '79', '44', '102', '88', '80', '72', '97', '68', '89', '38', '83',
#        '63', '148', '166', '90', '76', '37', '70', '124', '94', '140',
#        '153', '107', '117', '121', '92', '78', '75', '114', '115', '130',
#        '128', '151', '110', '138', '135', '109', '61', '179', '170',
#        '112', '116', '91', '143', '93', '123', '145', '81', '150', '162',
# ...

# %%
df.head(1)
# Out:
#   Innings Player Innings Runs Scored Innings Runs Scored Num  \
# 0        E Lewis                  65                      65
#
#   Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 0                    128                  1.0                   0.0
#
#   Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# 0                  80                      8                      1
#
#   Innings Batting Strike Rate  ... Innings Overs Bowled Innings Bowled Flag  \
# 0                       81.25  ...                  NaN                 NaN
#
#   Innings Maidens Bowled Innings Runs Conceded Innings Wickets Taken  \
# 0                    NaN                   NaN                   NaN
#
#    4 Wickets  5 Wickets 10 Wickets Innings Wickets Taken Buckets  \
# 0        NaN        NaN        NaN                           NaN
#
#    Innings Economy Rate
# 0                   NaN
#
# [1 rows x 28 columns]

# %%
df['Innings Date'] = pd.to_datetime(df['Innings Date'])
# Out:
# <ipython-input-28-c1d5c1cc0f2c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Innings Date'] = pd.to_datetime(df['Innings Date'])

# %%
df['year'] = df['Innings Date'].dt.year
# Out:
# <ipython-input-29-0595cad78730>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = df['Innings Date'].dt.year

# %%
df.head(1)
# Out:
#   Innings Player Innings Runs Scored Innings Runs Scored Num  \
# 0        E Lewis                  65                      65
#
#   Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 0                    128                  1.0                   0.0
#
#   Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# 0                  80                      8                      1
#
#   Innings Batting Strike Rate  ... Innings Bowled Flag Innings Maidens Bowled  \
# 0                       81.25  ...                 NaN                    NaN
#
#   Innings Runs Conceded Innings Wickets Taken 4 Wickets  5 Wickets  \
# 0                   NaN                   NaN       NaN        NaN
#
#    10 Wickets Innings Wickets Taken Buckets Innings Economy Rate  year
# 0         NaN                           NaN                  NaN  2019
#
# [1 rows x 29 columns]

# %%
df['Innings Runs Scored Num'] = df['Innings Runs Scored Num'].astype(int)
# Out:
# <ipython-input-47-a6128ef8f7ad>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Innings Runs Scored Num'] = df['Innings Runs Scored Num'].astype(int)

# %%
df['Innings Balls Faced'] = df['Innings Balls Faced'].astype(int)
# Out:
# <ipython-input-49-efe5b2917b38>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Innings Balls Faced'] = df['Innings Balls Faced'].astype(int)

# %%
df['Innings Not Out Flag'] = df['Innings Not Out Flag'].astype(int)
# Out:
# <ipython-input-51-047f45934f4a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Innings Not Out Flag'] = df['Innings Not Out Flag'].astype(int)

# %%
sachin_df = df[(df.year>=1994) & (df.year<=2004)]

# %%
virat_df = df[(df.year>=2009) & (df.year<=2019)]

# %%
sachin_df.head(2)
# Out:
# Empty DataFrame
# Columns: [Innings Player, Innings Runs Scored, Innings Runs Scored Num, Innings Minutes Batted, Innings Batted Flag, Innings Not Out Flag, Innings Balls Faced, Innings Boundary Fours, Innings Boundary Sixes, Innings Batting Strike Rate, Innings Number, Opposition, Ground, Innings Date, Country, 50's, 100's, Innings Runs Scored Buckets, Innings Overs Bowled, Innings Bowled Flag, Innings Maidens Bowled, Innings Runs Conceded, Innings Wickets Taken, 4 Wickets, 5 Wickets, 10 Wickets, Innings Wickets Taken Buckets, Innings Economy Rate, year]
# Index: []
#
# [0 rows x 29 columns]

# %%
virat_df.head(2)
# Out:
#   Innings Player Innings Runs Scored Innings Runs Scored Num  \
# 0        E Lewis                  65                      65
# 1       N Pooran                  42                      42
#
#   Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 0                    128                  1.0                   0.0
# 1                     69                  1.0                   0.0
#
#   Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# 0                  80                      8                      1
# 1                  52                      4                      1
#
#   Innings Batting Strike Rate  ... Innings Bowled Flag Innings Maidens Bowled  \
# 0                       81.25  ...                 NaN                    NaN
# 1                       80.76  ...                 NaN                    NaN
#
#   Innings Runs Conceded Innings Wickets Taken 4 Wickets  5 Wickets  \
# ...

# %%
df.dtypes
# Out:
# Innings Player                           object
# Innings Runs Scored                      object
# Innings Runs Scored Num                   int64
# Innings Minutes Batted                   object
# Innings Batted Flag                     float64
# Innings Not Out Flag                      int64
# Innings Balls Faced                       int64
# Innings Boundary Fours                   object
# Innings Boundary Sixes                   object
# Innings Batting Strike Rate              object
# Innings Number                           object
# Opposition                               object
# Ground                                   object
# Innings Date                     datetime64[ns]
# Country                                  object
# 50's                                    float64
# 100's                                   float64
# Innings Runs Scored Buckets              object
# Innings Overs Bowled                     object
# Innings Bowled Flag                     float64
# ...

# %%
sdf = sachin_df[sachin_df['Innings Player']=='Sachin Tendulkar']

# %%
sdf.head(2)
# Out:
# Empty DataFrame
# Columns: [Innings Player, Innings Runs Scored, Innings Runs Scored Num, Innings Minutes Batted, Innings Batted Flag, Innings Not Out Flag, Innings Balls Faced, Innings Boundary Fours, Innings Boundary Sixes, Innings Batting Strike Rate, Innings Number, Opposition, Ground, Innings Date, Country, 50's, 100's, Innings Runs Scored Buckets, Innings Overs Bowled, Innings Bowled Flag, Innings Maidens Bowled, Innings Runs Conceded, Innings Wickets Taken, 4 Wickets, 5 Wickets, 10 Wickets, Innings Wickets Taken Buckets, Innings Economy Rate, year]
# Index: []
#
# [0 rows x 29 columns]

# %%
sum(sdf['Innings Runs Scored Num'])
# Out:
# 0

# %%
vdf = virat_df[virat_df['Innings Player']=='Virat Kohli']

# %%
sum(vdf['Innings Runs Scored Num'])
# Out:
# 0

# %%
vdf
# Out:
# Empty DataFrame
# Columns: [Innings Player, Innings Runs Scored, Innings Runs Scored Num, Innings Minutes Batted, Innings Batted Flag, Innings Not Out Flag, Innings Balls Faced, Innings Boundary Fours, Innings Boundary Sixes, Innings Batting Strike Rate, Innings Number, Opposition, Ground, Innings Date, Country, 50's, 100's, Innings Runs Scored Buckets, Innings Overs Bowled, Innings Bowled Flag, Innings Maidens Bowled, Innings Runs Conceded, Innings Wickets Taken, 4 Wickets, 5 Wickets, 10 Wickets, Innings Wickets Taken Buckets, Innings Economy Rate, year]
# Index: []
#
# [0 rows x 29 columns]

# %%
sum(df['Innings Runs Scored Num'])/len(vdf),sum(df['Innings Runs Scored Num'])/len(sdf)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-61-27d397ec802f> in <cell line: 1>()
# ----> 1 sum(df['Innings Runs Scored Num'])/len(vdf),sum(df['Innings Runs Scored Num'])/len(sdf)
#
# ZeroDivisionError: division by zero

# %%
if len(vdf) > 0:
    avg_virat = sum(df['Innings Runs Scored Num'])/len(vdf)
else:
    avg_virat = 0  # or any other appropriate value

if len(sdf) > 0:
    avg_all = sum(df['Innings Runs Scored Num'])/len(sdf)
else:
    avg_all = 0  # or any other appropriate value

avg_virat, avg_all
# Out:
# (0, 0)
